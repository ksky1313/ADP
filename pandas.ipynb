# %% [markdown]
# # Pandas
# 파이썬에서 사용하는 데이터 분석 라이브러리

# %%
import pandas as pd

# %% [markdown]
# ## 1. Series
# 1차원 데이터(정수, 실수, 문자열 등)

# %% [markdown]
# ### Series 객체 생성
# 예) 1월부터 4월까지 평균 온도 데이터(-20, -10, 10 20)

# %%
temp = pd.Series([-20, -10, 10, 20])
print(temp)
# Out:
# 0   -20
# 1   -10
# 2    10
# 3    20
# dtype: int64

# %%
temp[0]
# Out:
# -20

# %% [markdown]
# ### Serires 객체 생성(Index 지정)

# %%
temp = pd.Series([-20, -10, 10, 20], index=['Jan', 'Fab', 'Mar', 'Apr'])
temp
# Out:
# Jan   -20
# Fab   -10
# Mar    10
# Apr    20
# dtype: int64

# %%
temp['Jan']
# Out:
# -20

# %% [markdown]
# ## 2. DataFrame
# 2차원 데이터 (Series들의 모음)

# %% [markdown]
# ### 데이터 준비
# 사전 (dict) 자료구조를 통해 생성
#
# 예) 슬램덩크 주요 이물 8명에 대한 데이터

# %%
data = {
    '이름' : ['채치수', '정대만', '송태섭', '서태웅', '강백호', '변덕규', '황태산', '윤대협'],
    '학교' : ['북산고', '북산고', '북산고', '북산고', '북산고', '능남고', '능남고', '능남고'],
    '키' : [197, 184, 168, 187, 188, 202, 188, 190],
    '국어' : [90, 40, 80, 40, 15, 80, 55, 100],
    '영어' : [85, 35, 75, 60, 20, 100, 65, 85],
    '수학' : [100, 50, 70, 70, 10, 95, 45, 90],
    '과학' : [95, 55, 80, 75, 35, 85, 40, 95],
    '사회' : [85, 25, 75, 80, 10, 80, 35, 95],
    'SW특기' : ['Python', 'Java', 'Javascript', '', '', 'C', 'PYTHON', 'C#']
}
data
# Out:
# {'이름': ['채치수', '정대만', '송태섭', '서태웅', '강백호', '변덕규', '황태산', '윤대협'],
#  '학교': ['북산고', '북산고', '북산고', '북산고', '북산고', '능남고', '능남고', '능남고'],
#  '키': [197, 184, 168, 187, 188, 202, 188, 190],
#  '국어': [90, 40, 80, 40, 15, 80, 55, 100],
#  '영어': [85, 35, 75, 60, 20, 100, 65, 85],
#  '수학': [100, 50, 70, 70, 10, 95, 45, 90],
#  '과학': [95, 55, 80, 75, 35, 85, 40, 95],
#  '사회': [85, 25, 75, 80, 10, 80, 35, 95],
#  'SW특기': ['Python', 'Java', 'Javascript', '', '', 'C', 'PYTHON', 'C#']}

# %%
data['이름']
# Out:
# ['채치수', '정대만', '송태섭', '서태웅', '강백호', '변덕규', '황태산', '윤대협']

# %%
data['키']
# Out:
# [197, 184, 168, 187, 188, 202, 188, 190]

# %% [markdown]
# ### DataFrame 객체 생성

# %%
df = pd.DataFrame(data)
df
# Out:
#     이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 0  채치수  북산고  197   90   85  100  95  85      Python
# 1  정대만  북산고  184   40   35   50  55  25        Java
# 2  송태섭  북산고  168   80   75   70  80  75  Javascript
# 3  서태웅  북산고  187   40   60   70  75  80
# 4  강백호  북산고  188   15   20   10  35  10
# 5  변덕규  능남고  202   80  100   95  85  80           C
# 6  황태산  능남고  188   55   65   45  40  35      PYTHON
# 7  윤대협  능남고  190  100   85   90  95  95          C#

# %% [markdown]
# ### 데이터 접근

# %%
df[['이름', '키']]
# Out:
#     이름    키
# 0  채치수  197
# 1  정대만  184
# 2  송태섭  168
# 3  서태웅  187
# 4  강백호  188
# 5  변덕규  202
# 6  황태산  188
# 7  윤대협  190

# %% [markdown]
# ### DataFrame 객체 생성(컬럼 지정)

# %%
df = pd.DataFrame(data, columns=['학교', '키'])
df
# Out:
#     학교    키
# 0  북산고  197
# 1  북산고  184
# 2  북산고  168
# 3  북산고  187
# 4  북산고  188
# 5  능남고  202
# 6  능남고  188
# 7  능남고  190

# %% [markdown]
# ### DataFrame 객체 생성(Index 지정)

# %%
df = pd.DataFrame(data, index=['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h'])
df
# Out:
#     이름   학교    키   국어   영어   수학  과학  사회        SW특기
# a  채치수  북산고  197   90   85  100  95  85      Python
# b  정대만  북산고  184   40   35   50  55  25        Java
# c  송태섭  북산고  168   80   75   70  80  75  Javascript
# d  서태웅  북산고  187   40   60   70  75  80
# e  강백호  북산고  188   15   20   10  35  10
# f  변덕규  능남고  202   80  100   95  85  80           C
# g  황태산  능남고  188   55   65   45  40  35      PYTHON
# h  윤대협  능남고  190  100   85   90  95  95          C#

# %% [markdown]
# ## 3. Index
# 데이터에 접근할 수 있는 주소 값

# %%
df.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h'], dtype='object')

# %% [markdown]
# ### Index 이름 설정

# %%
df.index.name = 'no'
df
# Out:
#      이름   학교    키   국어   영어   수학  과학  사회        SW특기
# no
# a   채치수  북산고  197   90   85  100  95  85      Python
# b   정대만  북산고  184   40   35   50  55  25        Java
# c   송태섭  북산고  168   80   75   70  80  75  Javascript
# d   서태웅  북산고  187   40   60   70  75  80
# e   강백호  북산고  188   15   20   10  35  10
# f   변덕규  능남고  202   80  100   95  85  80           C
# g   황태산  능남고  188   55   65   45  40  35      PYTHON
# h   윤대협  능남고  190  100   85   90  95  95          C#

# %% [markdown]
# ### Index 초기화

# %%
df.reset_index()
# Out:
#   no   이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 0  a  채치수  북산고  197   90   85  100  95  85      Python
# 1  b  정대만  북산고  184   40   35   50  55  25        Java
# 2  c  송태섭  북산고  168   80   75   70  80  75  Javascript
# 3  d  서태웅  북산고  187   40   60   70  75  80
# 4  e  강백호  북산고  188   15   20   10  35  10
# 5  f  변덕규  능남고  202   80  100   95  85  80           C
# 6  g  황태산  능남고  188   55   65   45  40  35      PYTHON
# 7  h  윤대협  능남고  190  100   85   90  95  95          C#

# %%
df.reset_index(drop=True)
# Out:
#     이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 0  채치수  북산고  197   90   85  100  95  85      Python
# 1  정대만  북산고  184   40   35   50  55  25        Java
# 2  송태섭  북산고  168   80   75   70  80  75  Javascript
# 3  서태웅  북산고  187   40   60   70  75  80
# 4  강백호  북산고  188   15   20   10  35  10
# 5  변덕규  능남고  202   80  100   95  85  80           C
# 6  황태산  능남고  188   55   65   45  40  35      PYTHON
# 7  윤대협  능남고  190  100   85   90  95  95          C#

# %%
df.reset_index(drop=True, inplace=True)
df
# Out:
#     이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 0  채치수  북산고  197   90   85  100  95  85      Python
# 1  정대만  북산고  184   40   35   50  55  25        Java
# 2  송태섭  북산고  168   80   75   70  80  75  Javascript
# 3  서태웅  북산고  187   40   60   70  75  80
# 4  강백호  북산고  188   15   20   10  35  10
# 5  변덕규  능남고  202   80  100   95  85  80           C
# 6  황태산  능남고  188   55   65   45  40  35      PYTHON
# 7  윤대협  능남고  190  100   85   90  95  95          C#

# %% [markdown]
# ### Index 설정
# 지정한 Column으로 Index 설정

# %%
df.set_index('이름')
# Out:
#       학교    키   국어   영어   수학  과학  사회        SW특기
# 이름
# 채치수  북산고  197   90   85  100  95  85      Python
# 정대만  북산고  184   40   35   50  55  25        Java
# 송태섭  북산고  168   80   75   70  80  75  Javascript
# 서태웅  북산고  187   40   60   70  75  80
# 강백호  북산고  188   15   20   10  35  10
# 변덕규  능남고  202   80  100   95  85  80           C
# 황태산  능남고  188   55   65   45  40  35      PYTHON
# 윤대협  능남고  190  100   85   90  95  95          C#

# %%
df.set_index('이름', inplace=True)
df
# Out:
#       학교    키   국어   영어   수학  과학  사회        SW특기
# 이름
# 채치수  북산고  197   90   85  100  95  85      Python
# 정대만  북산고  184   40   35   50  55  25        Java
# 송태섭  북산고  168   80   75   70  80  75  Javascript
# 서태웅  북산고  187   40   60   70  75  80
# 강백호  북산고  188   15   20   10  35  10
# 변덕규  능남고  202   80  100   95  85  80           C
# 황태산  능남고  188   55   65   45  40  35      PYTHON
# 윤대협  능남고  190  100   85   90  95  95          C#

# %% [markdown]
# ### Index 정렬

# %%
df.sort_index()
# Out:
#       학교    키   국어   영어   수학  과학  사회        SW특기
# 이름
# 강백호  북산고  188   15   20   10  35  10
# 변덕규  능남고  202   80  100   95  85  80           C
# 서태웅  북산고  187   40   60   70  75  80
# 송태섭  북산고  168   80   75   70  80  75  Javascript
# 윤대협  능남고  190  100   85   90  95  95          C#
# 정대만  북산고  184   40   35   50  55  25        Java
# 채치수  북산고  197   90   85  100  95  85      Python
# 황태산  능남고  188   55   65   45  40  35      PYTHON

# %%
df.sort_index(ascending=False)
# Out:
#       학교    키   국어   영어   수학  과학  사회        SW특기
# 이름
# 황태산  능남고  188   55   65   45  40  35      PYTHON
# 채치수  북산고  197   90   85  100  95  85      Python
# 정대만  북산고  184   40   35   50  55  25        Java
# 윤대협  능남고  190  100   85   90  95  95          C#
# 송태섭  북산고  168   80   75   70  80  75  Javascript
# 서태웅  북산고  187   40   60   70  75  80
# 변덕규  능남고  202   80  100   95  85  80           C
# 강백호  북산고  188   15   20   10  35  10

# %% [markdown]
# ## 4. 파일 저장 및 열기
# DataFrame 객체를 파일로 저장 및 열기

# %%
df = pd.DataFrame(data, index=['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h'])
df.index.name = 'no'
df
# Out:
#      이름   학교    키   국어   영어   수학  과학  사회        SW특기
# no
# a   채치수  북산고  197   90   85  100  95  85      Python
# b   정대만  북산고  184   40   35   50  55  25        Java
# c   송태섭  북산고  168   80   75   70  80  75  Javascript
# d   서태웅  북산고  187   40   60   70  75  80
# e   강백호  북산고  188   15   20   10  35  10
# f   변덕규  능남고  202   80  100   95  85  80           C
# g   황태산  능남고  188   55   65   45  40  35      PYTHON
# h   윤대협  능남고  190  100   85   90  95  95          C#

# %% [markdown]
# ### 저장하기
# CSV 파일로 저장

# %%
df.to_csv('score.csv', encoding='utf-8-sig')

# %%
df.to_csv('score_no_index.csv', encoding='utf-8-sig', index=False)

# %% [markdown]
# #### txt 파일로 저장

# %%
df.to_csv('score.txt', encoding='utf-8-sig', sep='\t')

# %% [markdown]
# #### Excel 파일로 저장

# %%
df.to_excel('score.xlsx')

# %% [markdown]
# ### 열기
#
# CSV 파일 열기

# %%
df = pd.read_csv('score.csv')
df
# Out:
#   no   이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 0  a  채치수  북산고  197   90   85  100  95  85      Python
# 1  b  정대만  북산고  184   40   35   50  55  25        Java
# 2  c  송태섭  북산고  168   80   75   70  80  75  Javascript
# 3  d  서태웅  북산고  187   40   60   70  75  80         NaN
# 4  e  강백호  북산고  188   15   20   10  35  10         NaN
# 5  f  변덕규  능남고  202   80  100   95  85  80           C
# 6  g  황태산  능남고  188   55   65   45  40  35      PYTHON
# 7  h  윤대협  능남고  190  100   85   90  95  95          C#

# %%
df = pd.read_csv('score.csv', skiprows=5)
df
# Out:
#    e  강백호  북산고  188   15   20  10  35  10.1 Unnamed: 9
# 0  f  변덕규  능남고  202   80  100  95  85    80          C
# 1  g  황태산  능남고  188   55   65  45  40    35     PYTHON
# 2  h  윤대협  능남고  190  100   85  90  95    95         C#

# %%
df = pd.read_csv('score.csv', skiprows=[1, 3, 5])
df
# Out:
#   no   이름   학교    키   국어   영어  수학  과학  사회    SW특기
# 0  b  정대만  북산고  184   40   35  50  55  25    Java
# 1  d  서태웅  북산고  187   40   60  70  75  80     NaN
# 2  f  변덕규  능남고  202   80  100  95  85  80       C
# 3  g  황태산  능남고  188   55   65  45  40  35  PYTHON
# 4  h  윤대협  능남고  190  100   85  90  95  95      C#

# %%
df = pd.read_csv('score.csv', nrows=4)
df
# Out:
#   no   이름   학교    키  국어  영어   수학  과학  사회        SW특기
# 0  a  채치수  북산고  197  90  85  100  95  85      Python
# 1  b  정대만  북산고  184  40  35   50  55  25        Java
# 2  c  송태섭  북산고  168  80  75   70  80  75  Javascript
# 3  d  서태웅  북산고  187  40  60   70  75  80         NaN

# %%
df = pd.read_csv('score.csv', index_col='no')
df
# Out:
#      이름   학교    키   국어   영어   수학  과학  사회        SW특기
# no
# a   채치수  북산고  197   90   85  100  95  85      Python
# b   정대만  북산고  184   40   35   50  55  25        Java
# c   송태섭  북산고  168   80   75   70  80  75  Javascript
# d   서태웅  북산고  187   40   60   70  75  80         NaN
# e   강백호  북산고  188   15   20   10  35  10         NaN
# f   변덕규  능남고  202   80  100   95  85  80           C
# g   황태산  능남고  188   55   65   45  40  35      PYTHON
# h   윤대협  능남고  190  100   85   90  95  95          C#

# %% [markdown]
# #### Excel 파일 열기

# %%
df = pd.read_excel('score.xlsx', index_col='no')
df
# Out:
#      이름   학교    키   국어   영어   수학  과학  사회        SW특기
# no
# a   채치수  북산고  197   90   85  100  95  85      Python
# b   정대만  북산고  184   40   35   50  55  25        Java
# c   송태섭  북산고  168   80   75   70  80  75  Javascript
# d   서태웅  북산고  187   40   60   70  75  80         NaN
# e   강백호  북산고  188   15   20   10  35  10         NaN
# f   변덕규  능남고  202   80  100   95  85  80           C
# g   황태산  능남고  188   55   65   45  40  35      PYTHON
# h   윤대협  능남고  190  100   85   90  95  95          C#

# %% [markdown]
# ## 5. 데이터확인

# %% [markdown]
# ### DataFrame 확인
# 숫자 데이터에 대해 갯수, 평균, 표준편차, 최소/최대값 등의 정보를 보여줌

# %%
df.describe()
# Out:
#                 키          국어          영어          수학         과학         사회
# count    8.000000    8.000000    8.000000    8.000000   8.000000   8.000000
# mean   188.000000   62.500000   65.625000   66.250000  70.000000  60.625000
# std      9.985704   29.519969   26.917533   30.325614  23.754699  32.120032
# min    168.000000   15.000000   20.000000   10.000000  35.000000  10.000000
# 25%    186.250000   40.000000   53.750000   48.750000  51.250000  32.500000
# 50%    188.000000   67.500000   70.000000   70.000000  77.500000  77.500000
# 75%    191.750000   82.500000   85.000000   91.250000  87.500000  81.250000
# max    202.000000  100.000000  100.000000  100.000000  95.000000  95.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, a to h
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   이름      8 non-null      object
#  1   학교      8 non-null      object
#  2   키       8 non-null      int64
#  3   국어      8 non-null      int64
#  4   영어      8 non-null      int64
#  5   수학      8 non-null      int64
#  6   과학      8 non-null      int64
#  7   사회      8 non-null      int64
#  8   SW특기    6 non-null      object
# dtypes: int64(6), object(3)
# memory usage: 640.0+ bytes

# %%
df.head()
# Out:
#      이름   학교    키  국어  영어   수학  과학  사회        SW특기
# no
# a   채치수  북산고  197  90  85  100  95  85      Python
# b   정대만  북산고  184  40  35   50  55  25        Java
# c   송태섭  북산고  168  80  75   70  80  75  Javascript
# d   서태웅  북산고  187  40  60   70  75  80         NaN
# e   강백호  북산고  188  15  20   10  35  10         NaN

# %%
df.tail()
# Out:
#      이름   학교    키   국어   영어  수학  과학  사회    SW특기
# no
# d   서태웅  북산고  187   40   60  70  75  80     NaN
# e   강백호  북산고  188   15   20  10  35  10     NaN
# f   변덕규  능남고  202   80  100  95  85  80       C
# g   황태산  능남고  188   55   65  45  40  35  PYTHON
# h   윤대협  능남고  190  100   85  90  95  95      C#

# %%
df.values
# Out:
# array([['채치수', '북산고', 197, 90, 85, 100, 95, 85, 'Python'],
#        ['정대만', '북산고', 184, 40, 35, 50, 55, 25, 'Java'],
#        ['송태섭', '북산고', 168, 80, 75, 70, 80, 75, 'Javascript'],
#        ['서태웅', '북산고', 187, 40, 60, 70, 75, 80, nan],
#        ['강백호', '북산고', 188, 15, 20, 10, 35, 10, nan],
#        ['변덕규', '능남고', 202, 80, 100, 95, 85, 80, 'C'],
#        ['황태산', '능남고', 188, 55, 65, 45, 40, 35, 'PYTHON'],
#        ['윤대협', '능남고', 190, 100, 85, 90, 95, 95, 'C#']], dtype=object)

# %%
df.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h'], dtype='object', name='no')

# %%
df.columns
# Out:
# Index(['이름', '학교', '키', '국어', '영어', '수학', '과학', '사회', 'SW특기'], dtype='object')

# %%
df.shape
# Out:
# (8, 9)

# %% [markdown]
# ### Series 확인

# %%
df['키'].describe()
# Out:
# count      8.000000
# mean     188.000000
# std        9.985704
# min      168.000000
# 25%      186.250000
# 50%      188.000000
# 75%      191.750000
# max      202.000000
# Name: 키, dtype: float64

# %%
df['키'].mean()
# Out:
# 188.0

# %%
df['키'].nlargest(3)
# Out:
# no
# f    202
# a    197
# h    190
# Name: 키, dtype: int64

# %%
df['키'].nsmallest(3)
# Out:
# no
# c    168
# b    184
# d    187
# Name: 키, dtype: int64

# %%
df['키'].count()
# Out:
# 8

# %%
df['학교'].unique()
# Out:
# array(['북산고', '능남고'], dtype=object)

# %%
df['학교'].nunique()
# Out:
# 2

# %% [markdown]
# ## 6. 데이터 선택(기본)

# %%
df
# Out:
#      이름   학교    키   국어   영어   수학  과학  사회        SW특기
# no
# a   채치수  북산고  197   90   85  100  95  85      Python
# b   정대만  북산고  184   40   35   50  55  25        Java
# c   송태섭  북산고  168   80   75   70  80  75  Javascript
# d   서태웅  북산고  187   40   60   70  75  80         NaN
# e   강백호  북산고  188   15   20   10  35  10         NaN
# f   변덕규  능남고  202   80  100   95  85  80           C
# g   황태산  능남고  188   55   65   45  40  35      PYTHON
# h   윤대협  능남고  190  100   85   90  95  95          C#

# %% [markdown]
# ### 컬럼 선택

# %%
df['이름']
# Out:
# no
# a    채치수
# b    정대만
# c    송태섭
# d    서태웅
# e    강백호
# f    변덕규
# g    황태산
# h    윤대협
# Name: 이름, dtype: object

# %% [markdown]
# ### 컬럼 선택(정수 인덱스)

# %%
df.columns[0]
# Out:
# '이름'

# %%
df[df.columns[1]]
# Out:
# no
# a    북산고
# b    북산고
# c    북산고
# d    북산고
# e    북산고
# f    능남고
# g    능남고
# h    능남고
# Name: 학교, dtype: object

# %%
df[df.columns[-1]]
# Out:
# no
# a        Python
# b          Java
# c    Javascript
# d           NaN
# e           NaN
# f             C
# g        PYTHON
# h            C#
# Name: SW특기, dtype: object

# %%
df['이름'][1:5]
# Out:
# no
# b    정대만
# c    송태섭
# d    서태웅
# e    강백호
# Name: 이름, dtype: object

# %%
df[['이름', '키']][1:5]
# Out:
#      이름    키
# no
# b   정대만  184
# c   송태섭  168
# d   서태웅  187
# e   강백호  188

# %%
df[2:6]
# Out:
#      이름   학교    키  국어   영어  수학  과학  사회        SW특기
# no
# c   송태섭  북산고  168  80   75  70  80  75  Javascript
# d   서태웅  북산고  187  40   60  70  75  80         NaN
# e   강백호  북산고  188  15   20  10  35  10         NaN
# f   변덕규  능남고  202  80  100  95  85  80           C

# %% [markdown]
# ## 7. 데이터 선택(loc)

# %%
df.loc['a']
# Out:
# 이름         채치수
# 학교         북산고
# 키          197
# 국어          90
# 영어          85
# 수학         100
# 과학          95
# 사회          85
# SW특기    Python
# Name: a, dtype: object

# %%
df.loc['b', '키']
# Out:
# 184

# %%
df.loc[['a', 'b'], '키']
# Out:
# no
# a    197
# b    184
# Name: 키, dtype: int64

# %%
df.loc[['a', 'b'], ['이름', '키']]
# Out:
#      이름    키
# no
# a   채치수  197
# b   정대만  184

# %%
df.loc['a':'c', '이름':'키']
# Out:
#      이름   학교    키
# no
# a   채치수  북산고  197
# b   정대만  북산고  184
# c   송태섭  북산고  168

# %% [markdown]
# ## 8. 데이터 선택(iloc)
# 외치를 이용하여 원하는 row에서 원하는 col 선택

# %%
df
# Out:
#      이름   학교    키   국어   영어   수학  과학  사회        SW특기
# no
# a   채치수  북산고  197   90   85  100  95  85      Python
# b   정대만  북산고  184   40   35   50  55  25        Java
# c   송태섭  북산고  168   80   75   70  80  75  Javascript
# d   서태웅  북산고  187   40   60   70  75  80         NaN
# e   강백호  북산고  188   15   20   10  35  10         NaN
# f   변덕규  능남고  202   80  100   95  85  80           C
# g   황태산  능남고  188   55   65   45  40  35      PYTHON
# h   윤대협  능남고  190  100   85   90  95  95          C#

# %%
df.iloc[0]
# Out:
# 이름         채치수
# 학교         북산고
# 키          197
# 국어          90
# 영어          85
# 수학         100
# 과학          95
# 사회          85
# SW특기    Python
# Name: a, dtype: object

# %%
df.iloc[0:5, 0:1]
# Out:
#      이름
# no
# a   채치수
# b   정대만
# c   송태섭
# d   서태웅
# e   강백호

# %%
df.iloc[[0,1], 2]
# Out:
# no
# a    197
# b    184
# Name: 키, dtype: int64

# %% [markdown]
# ## 9. 데이터 선택(조건)

# %%
df['키'] >= 185
# Out:
# no
# a     True
# b    False
# c    False
# d     True
# e     True
# f     True
# g     True
# h     True
# Name: 키, dtype: bool

# %%
Filter = (df['키'] >= 185)
df[Filter]
# Out:
#      이름   학교    키   국어   영어   수학  과학  사회    SW특기
# no
# a   채치수  북산고  197   90   85  100  95  85  Python
# d   서태웅  북산고  187   40   60   70  75  80     NaN
# e   강백호  북산고  188   15   20   10  35  10     NaN
# f   변덕규  능남고  202   80  100   95  85  80       C
# g   황태산  능남고  188   55   65   45  40  35  PYTHON
# h   윤대협  능남고  190  100   85   90  95  95      C#

# %%
df[~Filter]
# Out:
#      이름   학교    키  국어  영어  수학  과학  사회        SW특기
# no
# b   정대만  북산고  184  40  35  50  55  25        Java
# c   송태섭  북산고  168  80  75  70  80  75  Javascript

# %%
df[df['키'] >= 185]
# Out:
#      이름   학교    키   국어   영어   수학  과학  사회    SW특기
# no
# a   채치수  북산고  197   90   85  100  95  85  Python
# d   서태웅  북산고  187   40   60   70  75  80     NaN
# e   강백호  북산고  188   15   20   10  35  10     NaN
# f   변덕규  능남고  202   80  100   95  85  80       C
# g   황태산  능남고  188   55   65   45  40  35  PYTHON
# h   윤대협  능남고  190  100   85   90  95  95      C#

# %%
df.loc[Filter, ['이름', '학교']]
# Out:
#      이름   학교
# no
# a   채치수  북산고
# d   서태웅  북산고
# e   강백호  북산고
# f   변덕규  능남고
# g   황태산  능남고
# h   윤대협  능남고

# %% [markdown]
# ### 다양한 조건

# %%
df.loc[(df['키']>185) & (df['학교'] == '북산고')]
# Out:
#      이름   학교    키  국어  영어   수학  과학  사회    SW특기
# no
# a   채치수  북산고  197  90  85  100  95  85  Python
# d   서태웅  북산고  187  40  60   70  75  80     NaN
# e   강백호  북산고  188  15  20   10  35  10     NaN

# %%
df.loc[(df['키']<185) | (df['키']>200)]
# Out:
#      이름   학교    키  국어   영어  수학  과학  사회        SW특기
# no
# b   정대만  북산고  184  40   35  50  55  25        Java
# c   송태섭  북산고  168  80   75  70  80  75  Javascript
# f   변덕규  능남고  202  80  100  95  85  80           C

# %% [markdown]
# ### str 함수

# %%
Filter = df['이름'].str.startswith('송')
df[Filter]
# Out:
#      이름   학교    키  국어  영어  수학  과학  사회        SW특기
# no
# c   송태섭  북산고  168  80  75  70  80  75  Javascript

# %%
Filter = df['이름'].str.contains('태')
df[Filter]
# Out:
#      이름   학교    키  국어  영어  수학  과학  사회        SW특기
# no
# c   송태섭  북산고  168  80  75  70  80  75  Javascript
# d   서태웅  북산고  187  40  60  70  75  80         NaN
# g   황태산  능남고  188  55  65  45  40  35      PYTHON

# %%
df[~Filter]
# Out:
#      이름   학교    키   국어   영어   수학  과학  사회    SW특기
# no
# a   채치수  북산고  197   90   85  100  95  85  Python
# b   정대만  북산고  184   40   35   50  55  25    Java
# e   강백호  북산고  188   15   20   10  35  10     NaN
# f   변덕규  능남고  202   80  100   95  85  80       C
# h   윤대협  능남고  190  100   85   90  95  95      C#

# %%
Filter = df['이름'].isin(['정대만', '변덕규'])
df[Filter]
# Out:
#      이름   학교    키  국어   영어  수학  과학  사회  SW특기
# no
# b   정대만  북산고  184  40   35  50  55  25  Java
# f   변덕규  능남고  202  80  100  95  85  80     C

# %% [markdown]
# ### contains 함수의 na 처리

# %%
Filter = df['SW특기'].str.contains('Java')
df[Filter]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Work\ADP\pandas.ipynb Cell 109' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Work/ADP/pandas.ipynb#ch0000119?line=0'>1</a> Filter = df['SW특기'].str.contains('Java')
# ----> <a href='vscode-notebook-cell:/c%3A/Work/ADP/pandas.ipynb#ch0000119?line=1'>2</a> df[Filter]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3495, in DataFrame.__getitem__(self, key)
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=3491'>3492</a>     return self.where(key)
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=3493'>3494</a> # Do we have a (boolean) 1d indexer?
# -> <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=3494'>3495</a> if com.is_bool_indexer(key):
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=3495'>3496</a>     return self._getitem_bool_array(key)
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=3497'>3498</a> # We are left with two options: a single key, and a collection of keys,
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=3498'>3499</a> # We interpret tuples as collections only for non-MultiIndex
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\common.py:144, in is_bool_indexer(key)
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/common.py?line=139'>140</a>     na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/common.py?line=140'>141</a>     if lib.infer_dtype(key) == "boolean" and isna(key).any():
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/common.py?line=141'>142</a>         # Don't raise on e.g. ["A", "B", np.nan], see
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/common.py?line=142'>143</a>         #  test_loc_getitem_list_of_labels_categoricalindex_with_na
# --> <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/common.py?line=143'>144</a>         raise ValueError(na_msg)
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/common.py?line=144'>145</a>     return False
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/common.py?line=145'>146</a> return True
#
# ValueError: Cannot mask with non-boolean array containing NA / NaN values

# %%
Filter = df['SW특기'].str.contains('Java', na=False)
df[Filter]
# Out:
#      이름   학교    키  국어  영어  수학  과학  사회        SW특기
# no
# b   정대만  북산고  184  40  35  50  55  25        Java
# c   송태섭  북산고  168  80  75  70  80  75  Javascript

# %% [markdown]
# ## 10. 결측치

# %%
df.fillna('없음')
# Out:
#   no   이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 0  a  채치수  북산고  197   90   85  100  95  85      Python
# 1  b  정대만  북산고  184   40   35   50  55  25        Java
# 2  c  송태섭  북산고  168   80   75   70  80  75  Javascript
# 3  d  서태웅  북산고  187   40   60   70  75  80          없음
# 4  e  강백호  북산고  188   15   20   10  35  10          없음
# 5  f  변덕규  능남고  202   80  100   95  85  80           C
# 6  g  황태산  능남고  188   55   65   45  40  35      PYTHON
# 7  h  윤대협  능남고  190  100   85   90  95  95          C#

# %%
import numpy as np
df['학교'] = np.nan
df
# Out:
#   no   이름  학교    키   국어   영어   수학  과학  사회        SW특기
# 0  a  채치수 NaN  197   90   85  100  95  85      Python
# 1  b  정대만 NaN  184   40   35   50  55  25        Java
# 2  c  송태섭 NaN  168   80   75   70  80  75  Javascript
# 3  d  서태웅 NaN  187   40   60   70  75  80          모름
# 4  e  강백호 NaN  188   15   20   10  35  10          모름
# 5  f  변덕규 NaN  202   80  100   95  85  80           C
# 6  g  황태산 NaN  188   55   65   45  40  35      PYTHON
# 7  h  윤대협 NaN  190  100   85   90  95  95          C#

# %%
df.fillna('모름')
# Out:
#   no   이름  학교    키   국어   영어   수학  과학  사회        SW특기
# 0  a  채치수  모름  197   90   85  100  95  85      Python
# 1  b  정대만  모름  184   40   35   50  55  25        Java
# 2  c  송태섭  모름  168   80   75   70  80  75  Javascript
# 3  d  서태웅  모름  187   40   60   70  75  80          모름
# 4  e  강백호  모름  188   15   20   10  35  10          모름
# 5  f  변덕규  모름  202   80  100   95  85  80           C
# 6  g  황태산  모름  188   55   65   45  40  35      PYTHON
# 7  h  윤대협  모름  190  100   85   90  95  95          C#

# %%
df.fillna('모름', inplace=True)
df
# Out:
#   no   이름  학교    키   국어   영어   수학  과학  사회        SW특기
# 0  a  채치수  모름  197   90   85  100  95  85      Python
# 1  b  정대만  모름  184   40   35   50  55  25        Java
# 2  c  송태섭  모름  168   80   75   70  80  75  Javascript
# 3  d  서태웅  모름  187   40   60   70  75  80          모름
# 4  e  강백호  모름  188   15   20   10  35  10          모름
# 5  f  변덕규  모름  202   80  100   95  85  80           C
# 6  g  황태산  모름  188   55   65   45  40  35      PYTHON
# 7  h  윤대협  모름  190  100   85   90  95  95          C#

# %%
df = pd.read_csv('score.csv')
df
# Out:
#   no   이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 0  a  채치수  북산고  197   90   85  100  95  85      Python
# 1  b  정대만  북산고  184   40   35   50  55  25        Java
# 2  c  송태섭  북산고  168   80   75   70  80  75  Javascript
# 3  d  서태웅  북산고  187   40   60   70  75  80         NaN
# 4  e  강백호  북산고  188   15   20   10  35  10         NaN
# 5  f  변덕규  능남고  202   80  100   95  85  80           C
# 6  g  황태산  능남고  188   55   65   45  40  35      PYTHON
# 7  h  윤대협  능남고  190  100   85   90  95  95          C#

# %%
df['SW특기'].fillna('확인중', inplace=True)
df
# Out:
#   no   이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 0  a  채치수  북산고  197   90   85  100  95  85      Python
# 1  b  정대만  북산고  184   40   35   50  55  25        Java
# 2  c  송태섭  북산고  168   80   75   70  80  75  Javascript
# 3  d  서태웅  북산고  187   40   60   70  75  80         확인중
# 4  e  강백호  북산고  188   15   20   10  35  10         확인중
# 5  f  변덕규  능남고  202   80  100   95  85  80           C
# 6  g  황태산  능남고  188   55   65   45  40  35      PYTHON
# 7  h  윤대협  능남고  190  100   85   90  95  95          C#

# %% [markdown]
# ### 데이터 제외하기

# %%
df = pd.read_csv('score.csv')
df
# Out:
#   no   이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 0  a  채치수  북산고  197   90   85  100  95  85      Python
# 1  b  정대만  북산고  184   40   35   50  55  25        Java
# 2  c  송태섭  북산고  168   80   75   70  80  75  Javascript
# 3  d  서태웅  북산고  187   40   60   70  75  80         NaN
# 4  e  강백호  북산고  188   15   20   10  35  10         NaN
# 5  f  변덕규  능남고  202   80  100   95  85  80           C
# 6  g  황태산  능남고  188   55   65   45  40  35      PYTHON
# 7  h  윤대협  능남고  190  100   85   90  95  95          C#

# %%
df.dropna()
# Out:
#   no   이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 0  a  채치수  북산고  197   90   85  100  95  85      Python
# 1  b  정대만  북산고  184   40   35   50  55  25        Java
# 2  c  송태섭  북산고  168   80   75   70  80  75  Javascript
# 5  f  변덕규  능남고  202   80  100   95  85  80           C
# 6  g  황태산  능남고  188   55   65   45  40  35      PYTHON
# 7  h  윤대협  능남고  190  100   85   90  95  95          C#

# %%
df.dropna(inplace=True)
df
# Out:
#   no   이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 0  a  채치수  북산고  197   90   85  100  95  85      Python
# 1  b  정대만  북산고  184   40   35   50  55  25        Java
# 2  c  송태섭  북산고  168   80   75   70  80  75  Javascript
# 5  f  변덕규  능남고  202   80  100   95  85  80           C
# 6  g  황태산  능남고  188   55   65   45  40  35      PYTHON
# 7  h  윤대협  능남고  190  100   85   90  95  95          C#

# %%
df = pd.read_csv('score.csv')
df
# Out:
#   no   이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 0  a  채치수  북산고  197   90   85  100  95  85      Python
# 1  b  정대만  북산고  184   40   35   50  55  25        Java
# 2  c  송태섭  북산고  168   80   75   70  80  75  Javascript
# 3  d  서태웅  북산고  187   40   60   70  75  80         NaN
# 4  e  강백호  북산고  188   15   20   10  35  10         NaN
# 5  f  변덕규  능남고  202   80  100   95  85  80           C
# 6  g  황태산  능남고  188   55   65   45  40  35      PYTHON
# 7  h  윤대협  능남고  190  100   85   90  95  95          C#

# %% [markdown]
# ### dropna 고급
# - axis : index | columns
# - how : any | all

# %%
df.dropna(axis='index', how='any')
# Out:
#   no   이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 0  a  채치수  북산고  197   90   85  100  95  85      Python
# 1  b  정대만  북산고  184   40   35   50  55  25        Java
# 2  c  송태섭  북산고  168   80   75   70  80  75  Javascript
# 5  f  변덕규  능남고  202   80  100   95  85  80           C
# 6  g  황태산  능남고  188   55   65   45  40  35      PYTHON
# 7  h  윤대협  능남고  190  100   85   90  95  95          C#

# %%
df.dropna(axis='index', how='all')
# Out:
#   no   이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 0  a  채치수  북산고  197   90   85  100  95  85      Python
# 1  b  정대만  북산고  184   40   35   50  55  25        Java
# 2  c  송태섭  북산고  168   80   75   70  80  75  Javascript
# 3  d  서태웅  북산고  187   40   60   70  75  80         NaN
# 4  e  강백호  북산고  188   15   20   10  35  10         NaN
# 5  f  변덕규  능남고  202   80  100   95  85  80           C
# 6  g  황태산  능남고  188   55   65   45  40  35      PYTHON
# 7  h  윤대협  능남고  190  100   85   90  95  95          C#

# %%
df.dropna(axis='columns')
# Out:
#   no   이름   학교    키   국어   영어   수학  과학  사회
# 0  a  채치수  북산고  197   90   85  100  95  85
# 1  b  정대만  북산고  184   40   35   50  55  25
# 2  c  송태섭  북산고  168   80   75   70  80  75
# 3  d  서태웅  북산고  187   40   60   70  75  80
# 4  e  강백호  북산고  188   15   20   10  35  10
# 5  f  변덕규  능남고  202   80  100   95  85  80
# 6  g  황태산  능남고  188   55   65   45  40  35
# 7  h  윤대협  능남고  190  100   85   90  95  95

# %% [markdown]
# ## 11. 데이터 정렬

# %%
df.sort_values('키')
# Out:
#   no   이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 2  c  송태섭  북산고  168   80   75   70  80  75  Javascript
# 1  b  정대만  북산고  184   40   35   50  55  25        Java
# 3  d  서태웅  북산고  187   40   60   70  75  80         NaN
# 4  e  강백호  북산고  188   15   20   10  35  10         NaN
# 6  g  황태산  능남고  188   55   65   45  40  35      PYTHON
# 7  h  윤대협  능남고  190  100   85   90  95  95          C#
# 0  a  채치수  북산고  197   90   85  100  95  85      Python
# 5  f  변덕규  능남고  202   80  100   95  85  80           C

# %%
df.sort_values('키', ascending=False)
# Out:
#   no   이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 5  f  변덕규  능남고  202   80  100   95  85  80           C
# 0  a  채치수  북산고  197   90   85  100  95  85      Python
# 7  h  윤대협  능남고  190  100   85   90  95  95          C#
# 4  e  강백호  북산고  188   15   20   10  35  10         NaN
# 6  g  황태산  능남고  188   55   65   45  40  35      PYTHON
# 3  d  서태웅  북산고  187   40   60   70  75  80         NaN
# 1  b  정대만  북산고  184   40   35   50  55  25        Java
# 2  c  송태섭  북산고  168   80   75   70  80  75  Javascript

# %%
df.sort_values(['학교', '이름'], ascending=True)[['학교', '이름', '키']]
# Out:
#     학교   이름    키
# 5  능남고  변덕규  202
# 7  능남고  윤대협  190
# 6  능남고  황태산  188
# 4  북산고  강백호  188
# 3  북산고  서태웅  187
# 2  북산고  송태섭  168
# 1  북산고  정대만  184
# 0  북산고  채치수  197

# %%
df.sort_values(['학교', '이름'], ascending=[True, False])[['학교', '이름', '키']]
# Out:
#     학교   이름    키
# 6  능남고  황태산  188
# 7  능남고  윤대협  190
# 5  능남고  변덕규  202
# 0  북산고  채치수  197
# 1  북산고  정대만  184
# 2  북산고  송태섭  168
# 3  북산고  서태웅  187
# 4  북산고  강백호  188

# %%
df['키'].sort_values()
# Out:
# 2    168
# 1    184
# 3    187
# 4    188
# 6    188
# 7    190
# 0    197
# 5    202
# Name: 키, dtype: int64

# %%
df.sort_index(ascending=False)
# Out:
#   no   이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 7  h  윤대협  능남고  190  100   85   90  95  95          C#
# 6  g  황태산  능남고  188   55   65   45  40  35      PYTHON
# 5  f  변덕규  능남고  202   80  100   95  85  80           C
# 4  e  강백호  북산고  188   15   20   10  35  10         NaN
# 3  d  서태웅  북산고  187   40   60   70  75  80         NaN
# 2  c  송태섭  북산고  168   80   75   70  80  75  Javascript
# 1  b  정대만  북산고  184   40   35   50  55  25        Java
# 0  a  채치수  북산고  197   90   85  100  95  85      Python

# %% [markdown]
# ## 12. 데이터 수정

# %% [markdown]
# ### 컬럼 수정

# %%
df['학교'].replace({'북산고':'상북고', '능남고':'무슨고'})
# Out:
# 0    상북고
# 1    상북고
# 2    상북고
# 3    상북고
# 4    상북고
# 5    무슨고
# 6    무슨고
# 7    무슨고
# Name: 학교, dtype: object

# %%
df['학교'].replace({'북산고':'상북고', '능남고':'무슨고'}, inplace=True)
df
# Out:
#   no   이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 0  a  채치수  상북고  197   90   85  100  95  85      python
# 1  b  정대만  상북고  184   40   35   50  55  25        java
# 2  c  송태섭  상북고  168   80   75   70  80  75  javascript
# 3  d  서태웅  상북고  187   40   60   70  75  80         NaN
# 4  e  강백호  상북고  188   15   20   10  35  10         NaN
# 5  f  변덕규  무슨고  202   80  100   95  85  80           c
# 6  g  황태산  무슨고  188   55   65   45  40  35      python
# 7  h  윤대협  무슨고  190  100   85   90  95  95          c#

# %%
df['SW특기'] = df['SW특기'].str.lower()
df
# Out:
#   no   이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 0  a  채치수  상북고  197   90   85  100  95  85      python
# 1  b  정대만  상북고  184   40   35   50  55  25        java
# 2  c  송태섭  상북고  168   80   75   70  80  75  javascript
# 3  d  서태웅  상북고  187   40   60   70  75  80         NaN
# 4  e  강백호  상북고  188   15   20   10  35  10         NaN
# 5  f  변덕규  무슨고  202   80  100   95  85  80           c
# 6  g  황태산  무슨고  188   55   65   45  40  35      python
# 7  h  윤대협  무슨고  190  100   85   90  95  95          c#

# %%
df['학교'] = df['학교'] + "등학교"
df
# Out:
#   no   이름      학교    키   국어   영어   수학  과학  사회        SW특기
# 0  a  채치수  북산고등학교  197   90   85  100  95  85      Python
# 1  b  정대만  북산고등학교  184   40   35   50  55  25        Java
# 2  c  송태섭  북산고등학교  168   80   75   70  80  75  Javascript
# 3  d  서태웅  북산고등학교  187   40   60   70  75  80         NaN
# 4  e  강백호  북산고등학교  188   15   20   10  35  10         NaN
# 5  f  변덕규  능남고등학교  202   80  100   95  85  80           C
# 6  g  황태산  능남고등학교  188   55   65   45  40  35      PYTHON
# 7  h  윤대협  능남고등학교  190  100   85   90  95  95          C#

# %%
df['총합'] = df[df.columns[4:9]].sum(axis=1)
df
# Out:
#   no   이름      학교    키   국어   영어   수학  과학  사회        SW특기   총합
# 0  a  채치수  북산고등학교  197   90   85  100  95  85      Python  455
# 1  b  정대만  북산고등학교  184   40   35   50  55  25        Java  205
# 2  c  송태섭  북산고등학교  168   80   75   70  80  75  Javascript  380
# 3  d  서태웅  북산고등학교  187   40   60   70  75  80         NaN  325
# 4  e  강백호  북산고등학교  188   15   20   10  35  10         NaN   90
# 5  f  변덕규  능남고등학교  202   80  100   95  85  80           C  440
# 6  g  황태산  능남고등학교  188   55   65   45  40  35      PYTHON  240
# 7  h  윤대협  능남고등학교  190  100   85   90  95  95          C#  465

# %%
df['결과'] = 'Fail'
df
# Out:
#   no   이름      학교    키   국어   영어   수학  과학  사회        SW특기   총합    결과
# 0  a  채치수  북산고등학교  197   90   85  100  95  85      Python  455  Fail
# 1  b  정대만  북산고등학교  184   40   35   50  55  25        Java  205  Fail
# 2  c  송태섭  북산고등학교  168   80   75   70  80  75  Javascript  380  Fail
# 3  d  서태웅  북산고등학교  187   40   60   70  75  80         NaN  325  Fail
# 4  e  강백호  북산고등학교  188   15   20   10  35  10         NaN   90  Fail
# 5  f  변덕규  능남고등학교  202   80  100   95  85  80           C  440  Fail
# 6  g  황태산  능남고등학교  188   55   65   45  40  35      PYTHON  240  Fail
# 7  h  윤대협  능남고등학교  190  100   85   90  95  95          C#  465  Fail

# %%
df.loc[df['총합'] > 400, '결과'] = 'Pass'
df
# Out:
#   no   이름      학교    키   국어   영어   수학  과학  사회        SW특기   총합    결과
# 0  a  채치수  북산고등학교  197   90   85  100  95  85      Python  455  Pass
# 1  b  정대만  북산고등학교  184   40   35   50  55  25        Java  205  Fail
# 2  c  송태섭  북산고등학교  168   80   75   70  80  75  Javascript  380  Fail
# 3  d  서태웅  북산고등학교  187   40   60   70  75  80         NaN  325  Fail
# 4  e  강백호  북산고등학교  188   15   20   10  35  10         NaN   90  Fail
# 5  f  변덕규  능남고등학교  202   80  100   95  85  80           C  440  Pass
# 6  g  황태산  능남고등학교  188   55   65   45  40  35      PYTHON  240  Fail
# 7  h  윤대협  능남고등학교  190  100   85   90  95  95          C#  465  Pass

# %% [markdown]
# ### 컬럼 삭제

# %%
df.drop(columns = ['총합'])
# Out:
#   no   이름      학교    키   국어   영어   수학  과학  사회        SW특기    결과
# 0  a  채치수  북산고등학교  197   90   85  100  95  85      Python  Pass
# 1  b  정대만  북산고등학교  184   40   35   50  55  25        Java  Fail
# 2  c  송태섭  북산고등학교  168   80   75   70  80  75  Javascript  Fail
# 3  d  서태웅  북산고등학교  187   40   60   70  75  80         NaN  Fail
# 4  e  강백호  북산고등학교  188   15   20   10  35  10         NaN  Fail
# 5  f  변덕규  능남고등학교  202   80  100   95  85  80           C  Pass
# 6  g  황태산  능남고등학교  188   55   65   45  40  35      PYTHON  Fail
# 7  h  윤대협  능남고등학교  190  100   85   90  95  95          C#  Pass

# %%
df.drop(columns = ['국어', '영어', '수학'])
# Out:
#   no   이름      학교    키  과학  사회        SW특기   총합    결과
# 0  a  채치수  북산고등학교  197  95  85      Python  455  Pass
# 1  b  정대만  북산고등학교  184  55  25        Java  205  Fail
# 2  c  송태섭  북산고등학교  168  80  75  Javascript  380  Fail
# 3  d  서태웅  북산고등학교  187  75  80         NaN  325  Fail
# 4  e  강백호  북산고등학교  188  35  10         NaN   90  Fail
# 5  f  변덕규  능남고등학교  202  85  80           C  440  Pass
# 6  g  황태산  능남고등학교  188  40  35      PYTHON  240  Fail
# 7  h  윤대협  능남고등학교  190  95  95          C#  465  Pass

# %% [markdown]
# ### Row 삭제

# %%
df.drop(index=2)
# Out:
#   no   이름      학교    키   국어   영어   수학  과학  사회    SW특기   총합    결과
# 0  a  채치수  북산고등학교  197   90   85  100  95  85  Python  455  Pass
# 1  b  정대만  북산고등학교  184   40   35   50  55  25    Java  205  Fail
# 3  d  서태웅  북산고등학교  187   40   60   70  75  80     NaN  325  Fail
# 4  e  강백호  북산고등학교  188   15   20   10  35  10     NaN   90  Fail
# 5  f  변덕규  능남고등학교  202   80  100   95  85  80       C  440  Pass
# 6  g  황태산  능남고등학교  188   55   65   45  40  35  PYTHON  240  Fail
# 7  h  윤대협  능남고등학교  190  100   85   90  95  95      C#  465  Pass

# %%
Filter = df['수학'] < 80
df.drop(index = df[Filter].index)
# Out:
#   no   이름      학교    키   국어   영어   수학  과학  사회    SW특기   총합    결과
# 0  a  채치수  북산고등학교  197   90   85  100  95  85  Python  455  Pass
# 5  f  변덕규  능남고등학교  202   80  100   95  85  80       C  440  Pass
# 7  h  윤대협  능남고등학교  190  100   85   90  95  95      C#  465  Pass

# %% [markdown]
# ### Row 추가

# %%
df = pd.read_csv('score.csv')

df.reset_index(drop=True, inplace=True)
df.set_index('no', inplace=True)
df
# Out:
#      이름   학교    키   국어   영어   수학  과학  사회        SW특기
# no
# a   채치수  북산고  197   90   85  100  95  85      Python
# b   정대만  북산고  184   40   35   50  55  25        Java
# c   송태섭  북산고  168   80   75   70  80  75  Javascript
# d   서태웅  북산고  187   40   60   70  75  80         NaN
# e   강백호  북산고  188   15   20   10  35  10         NaN
# f   변덕규  능남고  202   80  100   95  85  80           C
# g   황태산  능남고  188   55   65   45  40  35      PYTHON
# h   윤대협  능남고  190  100   85   90  95  95          C#

# %%
df.loc['i'] = ['이정현', '해남고등학교', 184, 90, 90, 90, 90, 90, 'Fotran']
df
# Out:
#      이름      학교    키   국어   영어   수학  과학  사회        SW특기
# no
# a   채치수     북산고  197   90   85  100  95  85      Python
# b   정대만     북산고  184   40   35   50  55  25        Java
# c   송태섭     북산고  168   80   75   70  80  75  Javascript
# d   서태웅     북산고  187   40   60   70  75  80         NaN
# e   강백호     북산고  188   15   20   10  35  10         NaN
# f   변덕규     능남고  202   80  100   95  85  80           C
# g   황태산     능남고  188   55   65   45  40  35      PYTHON
# h   윤대협     능남고  190  100   85   90  95  95          C#
# i   이정현  해남고등학교  184   90   90   90  90  90      Fotran

# %%
df.loc['d', 'SW특기'] = 'Python'
df
# Out:
#      이름      학교    키   국어   영어   수학  과학  사회        SW특기
# no
# a   채치수     북산고  197   90   85  100  95  85      Python
# b   정대만     북산고  184   40   35   50  55  25        Java
# c   송태섭     북산고  168   80   75   70  80  75  Javascript
# d   서태웅     북산고  187   40   60   70  75  80      Python
# e   강백호     북산고  188   15   20   10  35  10         NaN
# f   변덕규     능남고  202   80  100   95  85  80           C
# g   황태산     능남고  188   55   65   45  40  35      PYTHON
# h   윤대협     능남고  190  100   85   90  95  95          C#
# i   이정현  해남고등학교  184   90   90   90  90  90      Fotran

# %%
df.loc['e', ['학교', 'SW특기']] = ['능남고', 'C']
df
# Out:
#      이름      학교    키   국어   영어   수학  과학  사회        SW특기
# no
# a   채치수     북산고  197   90   85  100  95  85      Python
# b   정대만     북산고  184   40   35   50  55  25        Java
# c   송태섭     북산고  168   80   75   70  80  75  Javascript
# d   서태웅     북산고  187   40   60   70  75  80      Python
# e   강백호     능남고  188   15   20   10  35  10           C
# f   변덕규     능남고  202   80  100   95  85  80           C
# g   황태산     능남고  188   55   65   45  40  35      PYTHON
# h   윤대협     능남고  190  100   85   90  95  95          C#
# i   이정현  해남고등학교  184   90   90   90  90  90      Fotran

# %% [markdown]
# ### Columns 순서 변경

# %%
cols = list(df.columns)
df[[cols[-1]]+cols[0:-1]]
# Out:
#           SW특기   이름      학교    키   국어   영어   수학  과학  사회
# no
# a       Python  채치수     북산고  197   90   85  100  95  85
# b         Java  정대만     북산고  184   40   35   50  55  25
# c   Javascript  송태섭     북산고  168   80   75   70  80  75
# d       Python  서태웅     북산고  187   40   60   70  75  80
# e            C  강백호     능남고  188   15   20   10  35  10
# f            C  변덕규     능남고  202   80  100   95  85  80
# g       PYTHON  황태산     능남고  188   55   65   45  40  35
# h           C#  윤대협     능남고  190  100   85   90  95  95
# i       Fotran  이정현  해남고등학교  184   90   90   90  90  90

# %%
temp = df[['학교', '이름']]
temp
# Out:
#         학교   이름
# no
# a      북산고  채치수
# b      북산고  정대만
# c      북산고  송태섭
# d      북산고  서태웅
# e      능남고  강백호
# f      능남고  변덕규
# g      능남고  황태산
# h      능남고  윤대협
# i   해남고등학교  이정현

# %%
temp.columns = ["School", "Name"]
temp
# Out:
#     School Name
# no
# a      북산고  채치수
# b      북산고  정대만
# c      북산고  송태섭
# d      북산고  서태웅
# e      능남고  강백호
# f      능남고  변덕규
# g      능남고  황태산
# h      능남고  윤대협
# i   해남고등학교  이정현
